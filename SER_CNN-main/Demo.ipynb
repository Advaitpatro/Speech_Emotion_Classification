# %%
import os
import matplotlib.pyplot as plt
from IPython.display import Image, display

print("=== SPEECH EMOTION RECOGNITION PROJECT ===")

# 1. Run Evaluation Script
print("\n[Step 1] Generating Evaluation Metrics & Confusion Matrix...")
# !python evaluate.py

# 2. Display the Confusion Matrix Image
print("\n[Step 2] Confusion Matrix Visualization:")
try:
    display(Image(filename='confusion_matrix.png'))
except:
    print("Error: confusion_matrix.png not found. Did evaluate.py run?")

# 3. Run a Live Prediction
# Note: We point to a sample file in the data folder
print("\n[Step 3] Live Inference Test (Actor 01 - Angry):")
# !python predict.py data/RAVDESS/Audio_Speech_Actors_01-24/Actor_01/03-01-05-01-01-01-01.wav
# Out:
# === SPEECH EMOTION RECOGNITION PROJECT ===
# Student: Emi
#
# [Step 1] Generating Evaluation Metrics & Confusion Matrix...
# Loading Test Data...
# Running Inference on Test Set...
#
# [+] Confusion Matrix saved as 'confusion_matrix.png'
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#      Neutral       0.64      0.70      0.67        10
#         Calm       0.64      0.84      0.73        19
#        Happy       0.67      0.32      0.43        19
#          Sad       0.39      0.63      0.48        19
#        Angry       0.67      0.53      0.59        19
#      Fearful       0.62      0.50      0.56        20
#      Disgust       0.60      0.47      0.53        19
#    Surprised       0.73      0.84      0.78        19
#
#     accuracy                           0.60       144
#    macro avg       0.62      0.60      0.59       144
# weighted avg       0.62      0.60      0.59       144
#
#
# --- Gender Bias / Pitch Analysis ---
# ...
